# %%
# !pip install -U peft transformers datasets accelerate bitsandbytes
# !pip install -q trl
# Out:
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (0.16.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.53.3)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (4.0.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.9.0)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.11/dist-packages (0.46.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from peft) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from peft) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from peft) (6.0.2)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from peft) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from peft) (4.67.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from peft) (0.5.3)
# Requirement already satisfied: huggingface_hub>=0.25.0 in /usr/local/lib/python3.11/dist-packages (from peft) (0.33.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.11.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.25.0->peft) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.25.0->peft) (1.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.7.14)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.13.0->peft) (3.0.2)

# %%
from datasets import load_dataset
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "bigscience/bloomz-560m"
tokenizer = AutoTokenizer.from_pretrained(model_name)
foundation_model = AutoModelForCausalLM.from_pretrained(model_name)

dataset = load_dataset("Abirate/english_quotes", split="train[:10%]")
data = dataset.map(lambda samples: tokenizer(samples["quote"]), batched=True)
train_sample = data.select(range(50))
display(train_sample)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Dataset({
#     features: ['quote', 'author', 'tags', 'input_ids', 'attention_mask'],
#     num_rows: 10
# })

# %%
import peft
from peft import LoraConfig, get_peft_model

lora_config = LoraConfig(
    r=1,
    lora_alpha=1, # a scaling factor that adjusts the magnitude of the weight matrix. Usually set to 1
    target_modules=["query_key_value"],
    lora_dropout=0.05,
    bias="none", # this specifies if the bias parameter should be trained.
    task_type="CAUSAL_LM"
)

peft_model = get_peft_model(foundation_model, lora_config)

# Set requires_grad to True for LoRA parameters
for name, param in peft_model.named_parameters():
    if "lora_" in name:
        param.requires_grad = True

print(peft_model.print_trainable_parameters())
# Out:
# trainable params: 98,304 || all params: 559,312,896 || trainable%: 0.0176
# None

# %%
# !pip install evaluate
# Out:
# Requirement already satisfied: evaluate in /usr/local/lib/python3.11/dist-packages (0.4.5)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.70.15)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.33.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from evaluate) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.11.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2025.7.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)

# %%
import numpy as np
import evaluate

# Charge la métrique accuracy
accuracy_metric = evaluate.load("accuracy")

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)

    mask = labels != -100
    preds = predictions[mask]
    labs = labels[mask]

    return accuracy_metric.compute(predictions=preds, references=labs)

# %%
for name, param in peft_model.named_parameters():
    print(f"{name}: requires_grad={param.requires_grad}")
# Out:
# base_model.model.transformer.word_embeddings.weight: requires_grad=False
# base_model.model.transformer.word_embeddings_layernorm.weight: requires_grad=False
# base_model.model.transformer.word_embeddings_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.0.input_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.0.input_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.0.self_attention.query_key_value.base_layer.weight: requires_grad=False
# base_model.model.transformer.h.0.self_attention.query_key_value.base_layer.bias: requires_grad=False
# base_model.model.transformer.h.0.self_attention.query_key_value.lora_A.default.weight: requires_grad=True
# base_model.model.transformer.h.0.self_attention.query_key_value.lora_B.default.weight: requires_grad=True
# base_model.model.transformer.h.0.self_attention.dense.weight: requires_grad=False
# base_model.model.transformer.h.0.self_attention.dense.bias: requires_grad=False
# base_model.model.transformer.h.0.post_attention_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.0.post_attention_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.0.mlp.dense_h_to_4h.weight: requires_grad=False
# base_model.model.transformer.h.0.mlp.dense_h_to_4h.bias: requires_grad=False
# base_model.model.transformer.h.0.mlp.dense_4h_to_h.weight: requires_grad=False
# base_model.model.transformer.h.0.mlp.dense_4h_to_h.bias: requires_grad=False
# base_model.model.transformer.h.1.input_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.1.input_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.1.self_attention.query_key_value.base_layer.weight: requires_grad=False
# base_model.model.transformer.h.1.self_attention.query_key_value.base_layer.bias: requires_grad=False
# base_model.model.transformer.h.1.self_attention.query_key_value.lora_A.default.weight: requires_grad=True
# base_model.model.transformer.h.1.self_attention.query_key_value.lora_B.default.weight: requires_grad=True
# base_model.model.transformer.h.1.self_attention.dense.weight: requires_grad=False
# base_model.model.transformer.h.1.self_attention.dense.bias: requires_grad=False
# base_model.model.transformer.h.1.post_attention_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.1.post_attention_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.1.mlp.dense_h_to_4h.weight: requires_grad=False
# base_model.model.transformer.h.1.mlp.dense_h_to_4h.bias: requires_grad=False
# base_model.model.transformer.h.1.mlp.dense_4h_to_h.weight: requires_grad=False
# base_model.model.transformer.h.1.mlp.dense_4h_to_h.bias: requires_grad=False
# base_model.model.transformer.h.2.input_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.2.input_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.2.self_attention.query_key_value.base_layer.weight: requires_grad=False
# base_model.model.transformer.h.2.self_attention.query_key_value.base_layer.bias: requires_grad=False
# base_model.model.transformer.h.2.self_attention.query_key_value.lora_A.default.weight: requires_grad=True
# base_model.model.transformer.h.2.self_attention.query_key_value.lora_B.default.weight: requires_grad=True
# base_model.model.transformer.h.2.self_attention.dense.weight: requires_grad=False
# base_model.model.transformer.h.2.self_attention.dense.bias: requires_grad=False
# base_model.model.transformer.h.2.post_attention_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.2.post_attention_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.2.mlp.dense_h_to_4h.weight: requires_grad=False
# base_model.model.transformer.h.2.mlp.dense_h_to_4h.bias: requires_grad=False
# base_model.model.transformer.h.2.mlp.dense_4h_to_h.weight: requires_grad=False
# base_model.model.transformer.h.2.mlp.dense_4h_to_h.bias: requires_grad=False
# base_model.model.transformer.h.3.input_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.3.input_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.3.self_attention.query_key_value.base_layer.weight: requires_grad=False
# base_model.model.transformer.h.3.self_attention.query_key_value.base_layer.bias: requires_grad=False
# base_model.model.transformer.h.3.self_attention.query_key_value.lora_A.default.weight: requires_grad=True
# base_model.model.transformer.h.3.self_attention.query_key_value.lora_B.default.weight: requires_grad=True
# base_model.model.transformer.h.3.self_attention.dense.weight: requires_grad=False
# base_model.model.transformer.h.3.self_attention.dense.bias: requires_grad=False
# base_model.model.transformer.h.3.post_attention_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.3.post_attention_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.3.mlp.dense_h_to_4h.weight: requires_grad=False
# base_model.model.transformer.h.3.mlp.dense_h_to_4h.bias: requires_grad=False
# base_model.model.transformer.h.3.mlp.dense_4h_to_h.weight: requires_grad=False
# base_model.model.transformer.h.3.mlp.dense_4h_to_h.bias: requires_grad=False
# base_model.model.transformer.h.4.input_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.4.input_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.4.self_attention.query_key_value.base_layer.weight: requires_grad=False
# base_model.model.transformer.h.4.self_attention.query_key_value.base_layer.bias: requires_grad=False
# base_model.model.transformer.h.4.self_attention.query_key_value.lora_A.default.weight: requires_grad=True
# base_model.model.transformer.h.4.self_attention.query_key_value.lora_B.default.weight: requires_grad=True
# base_model.model.transformer.h.4.self_attention.dense.weight: requires_grad=False
# base_model.model.transformer.h.4.self_attention.dense.bias: requires_grad=False
# base_model.model.transformer.h.4.post_attention_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.4.post_attention_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.4.mlp.dense_h_to_4h.weight: requires_grad=False
# base_model.model.transformer.h.4.mlp.dense_h_to_4h.bias: requires_grad=False
# base_model.model.transformer.h.4.mlp.dense_4h_to_h.weight: requires_grad=False
# base_model.model.transformer.h.4.mlp.dense_4h_to_h.bias: requires_grad=False
# base_model.model.transformer.h.5.input_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.5.input_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.5.self_attention.query_key_value.base_layer.weight: requires_grad=False
# base_model.model.transformer.h.5.self_attention.query_key_value.base_layer.bias: requires_grad=False
# base_model.model.transformer.h.5.self_attention.query_key_value.lora_A.default.weight: requires_grad=True
# base_model.model.transformer.h.5.self_attention.query_key_value.lora_B.default.weight: requires_grad=True
# base_model.model.transformer.h.5.self_attention.dense.weight: requires_grad=False
# base_model.model.transformer.h.5.self_attention.dense.bias: requires_grad=False
# base_model.model.transformer.h.5.post_attention_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.5.post_attention_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.5.mlp.dense_h_to_4h.weight: requires_grad=False
# base_model.model.transformer.h.5.mlp.dense_h_to_4h.bias: requires_grad=False
# base_model.model.transformer.h.5.mlp.dense_4h_to_h.weight: requires_grad=False
# base_model.model.transformer.h.5.mlp.dense_4h_to_h.bias: requires_grad=False
# base_model.model.transformer.h.6.input_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.6.input_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.6.self_attention.query_key_value.base_layer.weight: requires_grad=False
# base_model.model.transformer.h.6.self_attention.query_key_value.base_layer.bias: requires_grad=False
# base_model.model.transformer.h.6.self_attention.query_key_value.lora_A.default.weight: requires_grad=True
# base_model.model.transformer.h.6.self_attention.query_key_value.lora_B.default.weight: requires_grad=True
# base_model.model.transformer.h.6.self_attention.dense.weight: requires_grad=False
# base_model.model.transformer.h.6.self_attention.dense.bias: requires_grad=False
# base_model.model.transformer.h.6.post_attention_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.6.post_attention_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.6.mlp.dense_h_to_4h.weight: requires_grad=False
# base_model.model.transformer.h.6.mlp.dense_h_to_4h.bias: requires_grad=False
# base_model.model.transformer.h.6.mlp.dense_4h_to_h.weight: requires_grad=False
# base_model.model.transformer.h.6.mlp.dense_4h_to_h.bias: requires_grad=False
# base_model.model.transformer.h.7.input_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.7.input_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.7.self_attention.query_key_value.base_layer.weight: requires_grad=False
# base_model.model.transformer.h.7.self_attention.query_key_value.base_layer.bias: requires_grad=False
# base_model.model.transformer.h.7.self_attention.query_key_value.lora_A.default.weight: requires_grad=True
# base_model.model.transformer.h.7.self_attention.query_key_value.lora_B.default.weight: requires_grad=True
# base_model.model.transformer.h.7.self_attention.dense.weight: requires_grad=False
# base_model.model.transformer.h.7.self_attention.dense.bias: requires_grad=False
# base_model.model.transformer.h.7.post_attention_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.7.post_attention_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.7.mlp.dense_h_to_4h.weight: requires_grad=False
# base_model.model.transformer.h.7.mlp.dense_h_to_4h.bias: requires_grad=False
# base_model.model.transformer.h.7.mlp.dense_4h_to_h.weight: requires_grad=False
# base_model.model.transformer.h.7.mlp.dense_4h_to_h.bias: requires_grad=False
# base_model.model.transformer.h.8.input_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.8.input_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.8.self_attention.query_key_value.base_layer.weight: requires_grad=False
# base_model.model.transformer.h.8.self_attention.query_key_value.base_layer.bias: requires_grad=False
# base_model.model.transformer.h.8.self_attention.query_key_value.lora_A.default.weight: requires_grad=True
# base_model.model.transformer.h.8.self_attention.query_key_value.lora_B.default.weight: requires_grad=True
# base_model.model.transformer.h.8.self_attention.dense.weight: requires_grad=False
# base_model.model.transformer.h.8.self_attention.dense.bias: requires_grad=False
# base_model.model.transformer.h.8.post_attention_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.8.post_attention_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.8.mlp.dense_h_to_4h.weight: requires_grad=False
# base_model.model.transformer.h.8.mlp.dense_h_to_4h.bias: requires_grad=False
# base_model.model.transformer.h.8.mlp.dense_4h_to_h.weight: requires_grad=False
# base_model.model.transformer.h.8.mlp.dense_4h_to_h.bias: requires_grad=False
# base_model.model.transformer.h.9.input_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.9.input_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.9.self_attention.query_key_value.base_layer.weight: requires_grad=False
# base_model.model.transformer.h.9.self_attention.query_key_value.base_layer.bias: requires_grad=False
# base_model.model.transformer.h.9.self_attention.query_key_value.lora_A.default.weight: requires_grad=True
# base_model.model.transformer.h.9.self_attention.query_key_value.lora_B.default.weight: requires_grad=True
# base_model.model.transformer.h.9.self_attention.dense.weight: requires_grad=False
# base_model.model.transformer.h.9.self_attention.dense.bias: requires_grad=False
# base_model.model.transformer.h.9.post_attention_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.9.post_attention_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.9.mlp.dense_h_to_4h.weight: requires_grad=False
# base_model.model.transformer.h.9.mlp.dense_h_to_4h.bias: requires_grad=False
# base_model.model.transformer.h.9.mlp.dense_4h_to_h.weight: requires_grad=False
# base_model.model.transformer.h.9.mlp.dense_4h_to_h.bias: requires_grad=False
# base_model.model.transformer.h.10.input_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.10.input_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.10.self_attention.query_key_value.base_layer.weight: requires_grad=False
# base_model.model.transformer.h.10.self_attention.query_key_value.base_layer.bias: requires_grad=False
# base_model.model.transformer.h.10.self_attention.query_key_value.lora_A.default.weight: requires_grad=True
# base_model.model.transformer.h.10.self_attention.query_key_value.lora_B.default.weight: requires_grad=True
# base_model.model.transformer.h.10.self_attention.dense.weight: requires_grad=False
# base_model.model.transformer.h.10.self_attention.dense.bias: requires_grad=False
# base_model.model.transformer.h.10.post_attention_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.10.post_attention_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.10.mlp.dense_h_to_4h.weight: requires_grad=False
# base_model.model.transformer.h.10.mlp.dense_h_to_4h.bias: requires_grad=False
# base_model.model.transformer.h.10.mlp.dense_4h_to_h.weight: requires_grad=False
# base_model.model.transformer.h.10.mlp.dense_4h_to_h.bias: requires_grad=False
# base_model.model.transformer.h.11.input_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.11.input_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.11.self_attention.query_key_value.base_layer.weight: requires_grad=False
# base_model.model.transformer.h.11.self_attention.query_key_value.base_layer.bias: requires_grad=False
# base_model.model.transformer.h.11.self_attention.query_key_value.lora_A.default.weight: requires_grad=True
# base_model.model.transformer.h.11.self_attention.query_key_value.lora_B.default.weight: requires_grad=True
# base_model.model.transformer.h.11.self_attention.dense.weight: requires_grad=False
# base_model.model.transformer.h.11.self_attention.dense.bias: requires_grad=False
# base_model.model.transformer.h.11.post_attention_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.11.post_attention_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.11.mlp.dense_h_to_4h.weight: requires_grad=False
# base_model.model.transformer.h.11.mlp.dense_h_to_4h.bias: requires_grad=False
# base_model.model.transformer.h.11.mlp.dense_4h_to_h.weight: requires_grad=False
# base_model.model.transformer.h.11.mlp.dense_4h_to_h.bias: requires_grad=False
# base_model.model.transformer.h.12.input_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.12.input_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.12.self_attention.query_key_value.base_layer.weight: requires_grad=False
# base_model.model.transformer.h.12.self_attention.query_key_value.base_layer.bias: requires_grad=False
# base_model.model.transformer.h.12.self_attention.query_key_value.lora_A.default.weight: requires_grad=True
# base_model.model.transformer.h.12.self_attention.query_key_value.lora_B.default.weight: requires_grad=True
# base_model.model.transformer.h.12.self_attention.dense.weight: requires_grad=False
# base_model.model.transformer.h.12.self_attention.dense.bias: requires_grad=False
# base_model.model.transformer.h.12.post_attention_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.12.post_attention_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.12.mlp.dense_h_to_4h.weight: requires_grad=False
# base_model.model.transformer.h.12.mlp.dense_h_to_4h.bias: requires_grad=False
# base_model.model.transformer.h.12.mlp.dense_4h_to_h.weight: requires_grad=False
# base_model.model.transformer.h.12.mlp.dense_4h_to_h.bias: requires_grad=False
# base_model.model.transformer.h.13.input_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.13.input_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.13.self_attention.query_key_value.base_layer.weight: requires_grad=False
# base_model.model.transformer.h.13.self_attention.query_key_value.base_layer.bias: requires_grad=False
# base_model.model.transformer.h.13.self_attention.query_key_value.lora_A.default.weight: requires_grad=True
# base_model.model.transformer.h.13.self_attention.query_key_value.lora_B.default.weight: requires_grad=True
# base_model.model.transformer.h.13.self_attention.dense.weight: requires_grad=False
# base_model.model.transformer.h.13.self_attention.dense.bias: requires_grad=False
# base_model.model.transformer.h.13.post_attention_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.13.post_attention_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.13.mlp.dense_h_to_4h.weight: requires_grad=False
# base_model.model.transformer.h.13.mlp.dense_h_to_4h.bias: requires_grad=False
# base_model.model.transformer.h.13.mlp.dense_4h_to_h.weight: requires_grad=False
# base_model.model.transformer.h.13.mlp.dense_4h_to_h.bias: requires_grad=False
# base_model.model.transformer.h.14.input_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.14.input_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.14.self_attention.query_key_value.base_layer.weight: requires_grad=False
# base_model.model.transformer.h.14.self_attention.query_key_value.base_layer.bias: requires_grad=False
# base_model.model.transformer.h.14.self_attention.query_key_value.lora_A.default.weight: requires_grad=True
# base_model.model.transformer.h.14.self_attention.query_key_value.lora_B.default.weight: requires_grad=True
# base_model.model.transformer.h.14.self_attention.dense.weight: requires_grad=False
# base_model.model.transformer.h.14.self_attention.dense.bias: requires_grad=False
# base_model.model.transformer.h.14.post_attention_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.14.post_attention_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.14.mlp.dense_h_to_4h.weight: requires_grad=False
# base_model.model.transformer.h.14.mlp.dense_h_to_4h.bias: requires_grad=False
# base_model.model.transformer.h.14.mlp.dense_4h_to_h.weight: requires_grad=False
# base_model.model.transformer.h.14.mlp.dense_4h_to_h.bias: requires_grad=False
# base_model.model.transformer.h.15.input_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.15.input_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.15.self_attention.query_key_value.base_layer.weight: requires_grad=False
# base_model.model.transformer.h.15.self_attention.query_key_value.base_layer.bias: requires_grad=False
# base_model.model.transformer.h.15.self_attention.query_key_value.lora_A.default.weight: requires_grad=True
# base_model.model.transformer.h.15.self_attention.query_key_value.lora_B.default.weight: requires_grad=True
# base_model.model.transformer.h.15.self_attention.dense.weight: requires_grad=False
# base_model.model.transformer.h.15.self_attention.dense.bias: requires_grad=False
# base_model.model.transformer.h.15.post_attention_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.15.post_attention_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.15.mlp.dense_h_to_4h.weight: requires_grad=False
# base_model.model.transformer.h.15.mlp.dense_h_to_4h.bias: requires_grad=False
# base_model.model.transformer.h.15.mlp.dense_4h_to_h.weight: requires_grad=False
# base_model.model.transformer.h.15.mlp.dense_4h_to_h.bias: requires_grad=False
# base_model.model.transformer.h.16.input_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.16.input_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.16.self_attention.query_key_value.base_layer.weight: requires_grad=False
# base_model.model.transformer.h.16.self_attention.query_key_value.base_layer.bias: requires_grad=False
# base_model.model.transformer.h.16.self_attention.query_key_value.lora_A.default.weight: requires_grad=True
# base_model.model.transformer.h.16.self_attention.query_key_value.lora_B.default.weight: requires_grad=True
# base_model.model.transformer.h.16.self_attention.dense.weight: requires_grad=False
# base_model.model.transformer.h.16.self_attention.dense.bias: requires_grad=False
# base_model.model.transformer.h.16.post_attention_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.16.post_attention_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.16.mlp.dense_h_to_4h.weight: requires_grad=False
# base_model.model.transformer.h.16.mlp.dense_h_to_4h.bias: requires_grad=False
# base_model.model.transformer.h.16.mlp.dense_4h_to_h.weight: requires_grad=False
# base_model.model.transformer.h.16.mlp.dense_4h_to_h.bias: requires_grad=False
# base_model.model.transformer.h.17.input_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.17.input_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.17.self_attention.query_key_value.base_layer.weight: requires_grad=False
# base_model.model.transformer.h.17.self_attention.query_key_value.base_layer.bias: requires_grad=False
# base_model.model.transformer.h.17.self_attention.query_key_value.lora_A.default.weight: requires_grad=True
# base_model.model.transformer.h.17.self_attention.query_key_value.lora_B.default.weight: requires_grad=True
# base_model.model.transformer.h.17.self_attention.dense.weight: requires_grad=False
# base_model.model.transformer.h.17.self_attention.dense.bias: requires_grad=False
# base_model.model.transformer.h.17.post_attention_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.17.post_attention_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.17.mlp.dense_h_to_4h.weight: requires_grad=False
# base_model.model.transformer.h.17.mlp.dense_h_to_4h.bias: requires_grad=False
# base_model.model.transformer.h.17.mlp.dense_4h_to_h.weight: requires_grad=False
# base_model.model.transformer.h.17.mlp.dense_4h_to_h.bias: requires_grad=False
# base_model.model.transformer.h.18.input_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.18.input_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.18.self_attention.query_key_value.base_layer.weight: requires_grad=False
# base_model.model.transformer.h.18.self_attention.query_key_value.base_layer.bias: requires_grad=False
# base_model.model.transformer.h.18.self_attention.query_key_value.lora_A.default.weight: requires_grad=True
# base_model.model.transformer.h.18.self_attention.query_key_value.lora_B.default.weight: requires_grad=True
# base_model.model.transformer.h.18.self_attention.dense.weight: requires_grad=False
# base_model.model.transformer.h.18.self_attention.dense.bias: requires_grad=False
# base_model.model.transformer.h.18.post_attention_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.18.post_attention_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.18.mlp.dense_h_to_4h.weight: requires_grad=False
# base_model.model.transformer.h.18.mlp.dense_h_to_4h.bias: requires_grad=False
# base_model.model.transformer.h.18.mlp.dense_4h_to_h.weight: requires_grad=False
# base_model.model.transformer.h.18.mlp.dense_4h_to_h.bias: requires_grad=False
# base_model.model.transformer.h.19.input_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.19.input_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.19.self_attention.query_key_value.base_layer.weight: requires_grad=False
# base_model.model.transformer.h.19.self_attention.query_key_value.base_layer.bias: requires_grad=False
# base_model.model.transformer.h.19.self_attention.query_key_value.lora_A.default.weight: requires_grad=True
# base_model.model.transformer.h.19.self_attention.query_key_value.lora_B.default.weight: requires_grad=True
# base_model.model.transformer.h.19.self_attention.dense.weight: requires_grad=False
# base_model.model.transformer.h.19.self_attention.dense.bias: requires_grad=False
# base_model.model.transformer.h.19.post_attention_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.19.post_attention_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.19.mlp.dense_h_to_4h.weight: requires_grad=False
# base_model.model.transformer.h.19.mlp.dense_h_to_4h.bias: requires_grad=False
# base_model.model.transformer.h.19.mlp.dense_4h_to_h.weight: requires_grad=False
# base_model.model.transformer.h.19.mlp.dense_4h_to_h.bias: requires_grad=False
# base_model.model.transformer.h.20.input_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.20.input_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.20.self_attention.query_key_value.base_layer.weight: requires_grad=False
# base_model.model.transformer.h.20.self_attention.query_key_value.base_layer.bias: requires_grad=False
# base_model.model.transformer.h.20.self_attention.query_key_value.lora_A.default.weight: requires_grad=True
# base_model.model.transformer.h.20.self_attention.query_key_value.lora_B.default.weight: requires_grad=True
# base_model.model.transformer.h.20.self_attention.dense.weight: requires_grad=False
# base_model.model.transformer.h.20.self_attention.dense.bias: requires_grad=False
# base_model.model.transformer.h.20.post_attention_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.20.post_attention_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.20.mlp.dense_h_to_4h.weight: requires_grad=False
# base_model.model.transformer.h.20.mlp.dense_h_to_4h.bias: requires_grad=False
# base_model.model.transformer.h.20.mlp.dense_4h_to_h.weight: requires_grad=False
# base_model.model.transformer.h.20.mlp.dense_4h_to_h.bias: requires_grad=False
# base_model.model.transformer.h.21.input_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.21.input_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.21.self_attention.query_key_value.base_layer.weight: requires_grad=False
# base_model.model.transformer.h.21.self_attention.query_key_value.base_layer.bias: requires_grad=False
# base_model.model.transformer.h.21.self_attention.query_key_value.lora_A.default.weight: requires_grad=True
# base_model.model.transformer.h.21.self_attention.query_key_value.lora_B.default.weight: requires_grad=True
# base_model.model.transformer.h.21.self_attention.dense.weight: requires_grad=False
# base_model.model.transformer.h.21.self_attention.dense.bias: requires_grad=False
# base_model.model.transformer.h.21.post_attention_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.21.post_attention_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.21.mlp.dense_h_to_4h.weight: requires_grad=False
# base_model.model.transformer.h.21.mlp.dense_h_to_4h.bias: requires_grad=False
# base_model.model.transformer.h.21.mlp.dense_4h_to_h.weight: requires_grad=False
# base_model.model.transformer.h.21.mlp.dense_4h_to_h.bias: requires_grad=False
# base_model.model.transformer.h.22.input_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.22.input_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.22.self_attention.query_key_value.base_layer.weight: requires_grad=False
# base_model.model.transformer.h.22.self_attention.query_key_value.base_layer.bias: requires_grad=False
# base_model.model.transformer.h.22.self_attention.query_key_value.lora_A.default.weight: requires_grad=True
# base_model.model.transformer.h.22.self_attention.query_key_value.lora_B.default.weight: requires_grad=True
# base_model.model.transformer.h.22.self_attention.dense.weight: requires_grad=False
# base_model.model.transformer.h.22.self_attention.dense.bias: requires_grad=False
# base_model.model.transformer.h.22.post_attention_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.22.post_attention_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.22.mlp.dense_h_to_4h.weight: requires_grad=False
# base_model.model.transformer.h.22.mlp.dense_h_to_4h.bias: requires_grad=False
# base_model.model.transformer.h.22.mlp.dense_4h_to_h.weight: requires_grad=False
# base_model.model.transformer.h.22.mlp.dense_4h_to_h.bias: requires_grad=False
# base_model.model.transformer.h.23.input_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.23.input_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.23.self_attention.query_key_value.base_layer.weight: requires_grad=False
# base_model.model.transformer.h.23.self_attention.query_key_value.base_layer.bias: requires_grad=False
# base_model.model.transformer.h.23.self_attention.query_key_value.lora_A.default.weight: requires_grad=True
# base_model.model.transformer.h.23.self_attention.query_key_value.lora_B.default.weight: requires_grad=True
# base_model.model.transformer.h.23.self_attention.dense.weight: requires_grad=False
# base_model.model.transformer.h.23.self_attention.dense.bias: requires_grad=False
# base_model.model.transformer.h.23.post_attention_layernorm.weight: requires_grad=False
# base_model.model.transformer.h.23.post_attention_layernorm.bias: requires_grad=False
# base_model.model.transformer.h.23.mlp.dense_h_to_4h.weight: requires_grad=False
# base_model.model.transformer.h.23.mlp.dense_h_to_4h.bias: requires_grad=False
# base_model.model.transformer.h.23.mlp.dense_4h_to_h.weight: requires_grad=False
# base_model.model.transformer.h.23.mlp.dense_4h_to_h.bias: requires_grad=False
# base_model.model.transformer.ln_f.weight: requires_grad=False
# base_model.model.transformer.ln_f.bias: requires_grad=False

# %%
import transformers
from transformers import TrainingArguments, Trainer
import os

output_directory = os.path.join("../cache/working", "peft_lab_outputs")
training_args = TrainingArguments(
    report_to="none",
    output_dir=output_directory,
    auto_find_batch_size=True,
    learning_rate= 3e-2, # Higher learning rate than full fine-tuning.
    num_train_epochs=5,
    metric_for_best_model="accuracy",
    use_cpu=True
)

trainer = Trainer(
    model=peft_model,
    args=training_args,
    train_dataset=train_sample,
    data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False),
    compute_metrics=compute_metrics
)
trainer.train()
# Out:
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
#     <div>
#
#       <progress value='10' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10/10 01:28, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# TrainOutput(global_step=10, training_loss=13.447837829589844, metrics={'train_runtime': 103.9263, 'train_samples_per_second': 0.481, 'train_steps_per_second': 0.096, 'total_flos': 3919256616960.0, 'train_loss': 13.447837829589844, 'epoch': 5.0})

# %%
from peft import PeftModel, PeftConfig
import time

time_now = time.time()

peft_model_path = os.path.join(output_directory, f"peft_model_{time_now}")

trainer.model.save_pretrained(peft_model_path)

loaded_model = PeftModel.from_pretrained(foundation_model, peft_model_path, is_trainable=False)

inputs = tokenizer("Two things are infinite: ", return_tensors="pt")


outputs = peft_model.generate(
    input_ids=inputs["input_ids"],
    attention_mask=inputs["attention_mask"],
    max_new_tokens=10,
    eos_token_id=tokenizer.eos_token_id
    )

print(tokenizer.batch_decode(outputs, skip_special_tokens=True))
# Out:
# /usr/local/lib/python3.11/dist-packages/peft/tuners/tuners_utils.py:190: UserWarning: Already found a `peft_config` attribute in the model. This will lead to having multiple adapters in the model. Make sure to know what you are doing!
#   warnings.warn(
# ['Two things are infinite:  once once once once once once once once once once']
