# %%
import pandas as pd
# Exercise 1: Introduction to Data Analysis

# L’analyse de données consiste à étudier des données brutes pour en tirer des informations utiles. Elle utilise des outils statistiques et informatiques pour aider à comprendre, prévoir ou améliorer des situations.

# Avec la quantité énorme de données générées chaque jour, l’analyse permet de prendre de meilleures décisions, d’optimiser des services, de détecter des problèmes plus rapidement, et de créer de la valeur dans presque tous les domaines.
# Trois domaines d’application :

#     Santé : aide au diagnostic, détection de maladies, suivi de patients.

#     Marketing : personnalisation des publicités, analyse du comportement client.

#     Transport : optimisation des trajets, gestion de la logistique.

# %%
# Exercise 2: Dataset Loading and Initial Analysis
trained_data_credit_card = pd.read_csv(r'data_center\clean_dataset.csv')
print("DataSet qui affiche l'âge, le genre, si la personne est marié, les dettes etc..")
print(trained_data_credit_card.head())
trained_data_mental_health = pd.read_csv(r'data_center\Mental health Depression disorder Data.csv')
print("DataSet qui affiche la dépression lié aux employés d'une entreprise")
print(trained_data_mental_health.head())
trained_data_american_sleep = pd.read_csv(r'data_center\Time Americans Spend Sleeping.csv')
print("DataSet qui affiche l'origine, l'année de naissance et les différents problème de sommeils")
print(trained_data_american_sleep.head())

# Exercise 3: Identifying Data Types

# Pour le dataset sur les cartes de crédit (trained_data_credit_card):
#  0   Gender          Qualitative    int64  
#  1   Age             Quantitatif    float64
#  2   Debt            Quantitatif    float64
#  3   Married         Qualitative    int64  
#  4   BankCustomer    Qualitative    int64  
#  5   Industry        Qualitative    object 
#  6   Ethnicity       Qualitative    object 
#  7   YearsEmployed   Quantitatif    float64
#  8   PriorDefault    Qualitative    int64  
#  9   Employed        Qualitative    int64  
#  10  CreditScore     Quantitatif    int64  
#  11  DriversLicense  Qualitative    int64  
#  12  Citizen         Qualitative    object 
#  13  ZipCode         Qualitative    int64  
#  14  Income          Quantitatif    int64  
#  15  Approved        Qualitative    int64 



# Pour le dataset sur dépression en entreprise(trained_data_mental_health): 
# ---  ------                     --------------   -----  
#  0   index                      Quantitatif  int64  
#  1   Entity                     Qualitative  object 
#  2   Code                       Qualitative  object 
#  3   Year                       Qualitative  object 
#  4   Schizophrenia (%)          Qualitative  object 
#  5   Bipolar disorder (%)       Qualitative  object 
#  6   Eating disorders (%)       Qualitative  object 
#  7   Anxiety disorders (%)      Quantitatif  float64
#  8   Drug use disorders (%)     Quantitatif  float64
#  9   Depression (%)             Quantitatif  float64
#  10  Alcohol use disorders (%)  Quantitatif  float64


#  Pour le dataset sur différents problème de sommeils(trained_data_american_sleep): 
#  ---  ------                    --------------  -----  
#  0   index                     Quantitatif    int64  
#  1   Year                      Quantitatif    int64  
#  2   Period                    Qualitative    object 
#  3   Avg hrs per day sleeping  Quantitatif    float64
#  4   Standard Error            Quantitatif    float64
#  5   Type of Days              Qualitative    object 
#  6   Age Group                 Qualitative    object 
#  7   Activity                  Qualitative    object 
#  8   Sex                       Qualitative    object

# %%
pd.set_option('display.max_columns', None)
print(trained_data_credit_card.info())
print(trained_data_credit_card.head())
print(trained_data_mental_health.info())
print(trained_data_mental_health.head())
print(trained_data_american_sleep.info())
print(trained_data_american_sleep.head())

# Exercise 4: Exploring Data Types

# ---  ------         --------------  -----  
#  0   Id             150 Quantitatif    int64  
#  1   SepalLengthCm  150 Quantitatif    float64
#  2   SepalWidthCm   150 Quantitatif    float64
#  3   PetalLengthCm  150 Quantitatif    float64
#  4   PetalWidthCm   150 Quantitatif    float64
#  5   Species        150 Qualitative    object 

#  Quantitatif = Id, SepalLengthCm, SepalWidthCm, PetalLengthCm
#  Qualitative = Species

# %%
trained_data_iris = pd.read_csv(r'data_center\Iris.csv')
print(trained_data_iris.info())
print(trained_data_iris.head())

# %%
# Exercise 5: Basic Data Analysis with Google Colab
import matplotlib.pyplot as plt
import seaborn as sns


mean_value = trained_data_iris['SepalLengthCm'].mean()
median_value = trained_data_iris['SepalLengthCm'].median()
mode_value = trained_data_iris['SepalLengthCm'].mode()[0]

plt.figure(figsize=(8,5))
sns.barplot(x='Species', y='SepalLengthCm', data=trained_data_iris, palette='pastel')
plt.title("Longueur moyenne du sépale par espèce")
plt.xlabel("Espèce")
plt.ylabel("Longueur moyenne du sépale (cm)")
plt.show()

# %%
# Exercise 6: Basic Observation Skills in Data Analysis

# Year + Avg hrs per day sleeping

# Analyse possible :
# ➡️ Analyse des tendances (trend analysis)

#     Permet d'observer l'évolution du temps moyen de sommeil des Américains au fil des années.

#     Intéressant pour identifier des changements sur le long terme (effets du mode de vie, pandémie, etc.).

# 🔹 2. Sex + Avg hrs per day sleeping

# Analyse possible :
# ➡️ Comparaison entre groupes (group comparison)

#     Permet de comparer la durée de sommeil entre les hommes et les femmes.

#     Utile pour des études sur les différences comportementales ou biologiques.

# 🔹 3. Type of Days (ex : week-end vs jours ouvrés)

# Analyse possible :
# ➡️ Analyse de variation selon les jours

#     Intéressant pour voir si les gens dorment plus les week-ends que la semaine.

#     Donne une idée des effets du travail sur le sommeil.

# 🔹 4. Age Group

# Analyse possible :
# ➡️ Comparaison selon les tranches d’âge

#     Pour voir si les jeunes dorment plus que les adultes ou les personnes âgées.

#     Pertinent pour des études en santé publique ou en sociologie.
