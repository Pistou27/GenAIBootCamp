# %% [markdown]
# Step 1: Craft a Prompt That Controls Output Tone, Format, and Length
#
# Using the following original text excerpt, write a prompt that:
#
#     Rewrites it in a friendly and clear tone
#     Uses bullet points to organize information
#     Paraphrases the original, avoiding direct quotations
#     Stays under 75 words total
#
#
# Input Text:
#
#     Employees must ensure that all remote access to internal systems is established via the approved secure VPN. Under no circumstances should unsecured connections or personal devices lacking endpoint protection be used to access proprietary data or sensitive communications.

# %% [markdown]
# To keep remote work safe and secure, remember these key points:
#
# - Always connect to company systems through the approved VPN.
#
# - Avoid using open or unprotected networks for work access.
#
# - Only work from devices with proper security tools installed.
#
# - These practices protect sensitive data and communications.

# %% [markdown]
# Step 2: Evaluate the Output
#
# Once you’ve generated the response, review it using the following criteria:
# Criteria 	Guiding Questions
# Relevance 	Does the output stick to the message of the source content?
# Clarity 	Is the message easier to understand for non-technical staff?
# Structure 	Is the information formatted into clear bullet points?
# Tone 	Is the language appropriate for internal employee communication?
# Length 	Does it stay under 75 words?
# Factual Accuracy 	Did the model make up or remove any critical security details?

# %% [markdown]
# Relevance
#
# - Yes, it fully reflects the original policy: VPN use, no insecure networks, no unprotected devices, and protecting sensitive data.
#
# Clarity
#
# - Much clearer than the original. Uses everyday words like “unprotected networks” and “proper security tools” instead of jargon. Easy for non-technical staff.
#
# Structure
#
# - Nicely broken down into a short intro + four bullet points. Readable at a glance.
#
# Tone
#
# - Friendly but professional. The phrase “remember these key points” softens the directive. Suitable for an internal newsletter.
#
# Length
#
# - 42 words (well under 75). Leaves room if you ever want to expand slightly.
#
# Factual Accuracy
#
# - Accurate to the original. Nothing critical omitted or altered. All important security requirements (VPN, no insecure connections, device protection) are preserved.

# %% [markdown]
# Step 3: Detect and Mitigate Hallucinations
#
# If the model adds extra content (e.g., new policy terms, technologies not in the input), write a revised version of your original prompt that strictly limits the model to the input only.
#
# For example, you might add:
#
#     “Only paraphrase the content in the input text. Do not add new recommendations or technologies.”

# %% [markdown]
# Step 4: Paraphrasing Deep Dive
#
# Now write a second version of the prompt that paraphrases the policy paragraph for a junior intern audience, using plain language and short phrases.
#
#     Use no more than 4 bullet points
#     Avoid any corporate or legal jargon
#     Keep the tone supportive and informative

# %% [markdown]
# When working remotely, keep things safe by following these simple rules:
#
# - Always log in through the company’s secure VPN.
#
# - Don’t use public Wi-Fi or unsafe networks.
#
# - Use only devices with security software installed.
#
# - This protects company information and messages.

# %% [markdown]
# Step 5: Quote Extraction Variant
#
# Sometimes, quoting is more effective than paraphrasing. Write a new prompt that extracts one direct quote from the original text that best captures the core security policy.
#
# Then answer:
#
#     In what kind of internal communication would quoting be more appropriate than paraphrasing?
#     When might quoting pose a risk?

# %% [markdown]
# Here’s the single best direct quote from your policy paragraph that captures the core security policy:
#
# "Employees must ensure that all remote access to internal systems is established via the approved secure VPN."
#
#
# 1. In what kind of internal communication would quoting be more appropriate than paraphrasing?
#
# When precision and authority are required, such as in:
#
# Compliance training modules
#
# Official HR or IT policy documents
#
# Security certification materials
#
# Audit reports or legal reviews
# In these cases, quoting avoids misinterpretation and ensures employees see the exact wording of the policy.
#
# 2. When might quoting pose a risk?
#
# When the original policy is full of dense, legal, or technical jargon, quoting may confuse employees.
#
# If the audience is non-technical staff or interns, quoting risks making the message less clear.
#
# It may also seem too formal or intimidating in casual communications like newsletters or Slack updates.
