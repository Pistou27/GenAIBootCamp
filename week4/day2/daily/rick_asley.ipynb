# %%
import matplotlib.pyplot as plt
import numpy as np

image_path = r"data_center\grayscale_matrix.csv"
gray_matrix = np.loadtxt(image_path, delimiter=",")
plt.imshow(gray_matrix, cmap="gray")
plt.title("NGGYU")
plt.axis("off")
plt.show()
