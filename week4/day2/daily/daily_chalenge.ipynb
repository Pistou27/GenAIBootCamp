# %% [markdown]
# Import du fichier

# %%
import pandas as pd
from skimpy import skim
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

# %%
df_power_plant = pd.read_csv(r'data_center\global_power_plant_database.csv', low_memory=False)

skim(df_power_plant)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 34936  │ │ string      │ 19    │                                                          │
# │ │ Number of columns │ 36     │ │ float64     │ 17    │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# ...

# %%
df_power_plant.info()

# %%
print(df_power_plant.isnull().sum())
#Pas de ligne dupliquées
print(df_power_plant.duplicated().sum())

# %%
df_power_plant.head().T

# %%
df_power_plant.shape

# %%
plt.figure(figsize=(12, 6))
plt.bar(df_power_plant['primary_fuel'].value_counts().index,df_power_plant['primary_fuel'].value_counts(), color='skyblue')
plt.title('Total des centrales')
plt.ylabel('Nombre de central (tout types)')
plt.xticks(rotation=90)
plt.show()

# %%
df_power_plant.drop(index = [0],inplace = True)
fuel_map = {'Coal':'Fossil','Gas':'Fossil','Gas':'Fossil','Oil':'Fossil','Petcoke':'Fossil','Geothermal':'Other_renewable','Biomass':'Other_renewable','Storage':'Other',
            'Cogeneration':'Other','Waste':'Other','Hydro':'Hydro','Nuclear':'Nuclear','Wind':'Wind','Solar':'Solar','Other':'Other'}
df_power_plant['fuel_type'] = df_power_plant.primary_fuel.map(fuel_map)
renewable = ['Hydro','Other_renewable','Wind','Solar']
df_power_plant['renewable'] = ['renewable' if i in renewable else 'non-renewable' for i in df_power_plant['fuel_type'] ]
df_power_plant.head()
# Out:
#   country country_long                                               name  \
# 1     AFG  Afghanistan                                       Kandahar DOG
# 2     AFG  Afghanistan                                       Kandahar JOL
# 3     AFG  Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 4     AFG  Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# 5     AFG  Afghanistan  Nangarhar (Darunta) Hydroelectric Power Plant ...
#
#       gppd_idnr  capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 1    WKS0070144        10.00   31.6700    65.7950        Solar         NaN
# 2    WKS0071196        10.00   31.6230    65.7920        Solar         NaN
# 3  GEODB0040541        66.00   34.5560    69.4787        Hydro         NaN
# 4  GEODB0040534       100.00   34.6410    69.7170        Hydro         NaN
# 5  GEODB0040536        11.55   34.4847    70.3633        Hydro         NaN
#
#   other_fuel2 other_fuel3  commissioning_year owner      source  \
# ...

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
#       2 world.head()
#
# File c:\Users\alexa\AppData\Local\Programs\Python\Python312\Lib\site-packages\geopandas\datasets\__init__.py:18, in get_path(dataset)
#      12 error_msg = (
#      13     "The geopandas.dataset has been deprecated and was removed in GeoPandas "
#      14     f"1.0. You can get the original '{dataset}' data from "
#      15     f"{ne_message if 'natural' in dataset else nybb_message}"
#      16 )
#      17 if dataset in _prev_available:
# ---> 18     raise AttributeError(error_msg)
#      19 else:
#      20     error_msg = (
#      21         "The geopandas.dataset has been deprecated and "
#      22         "was removed in GeoPandas 1.0. New sample datasets are now available "
# ...
